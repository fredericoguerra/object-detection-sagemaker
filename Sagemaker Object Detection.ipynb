# %% [markdown]
# # Download the Data

# %%
# !pip3 install tqdm
# !pip3 install pillow --upgrade
# Out:
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages (4.44.1)
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_tensorflow_p36/bin/python -m pip install --upgrade pip' command.
# Requirement already up-to-date: pillow in /home/ec2-user/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages (7.2.0)
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_tensorflow_p36/bin/python -m pip install --upgrade pip' command.

# %%
# %matplotlib inline

import os
import tarfile
import urllib
import shutil
import json
import random
import numpy as np
import boto3
import sagemaker

from tqdm import tqdm
from sagemaker.amazon.amazon_estimator import get_image_uri
from matplotlib import pyplot as plt
from xml.etree import ElementTree as ET
from PIL import Image, ImageDraw, ImageFont

urls = ['http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz',
        'http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz']

def download_and_extract(data_dir, download_dir):
    for url in urls:
        target_file = url.split('/')[-1]
        if target_file not in os.listdir(download_dir):
            print('Downloading', url)
            urllib.request.urlretrieve(url, os.path.join(download_dir, target_file))
            tf = tarfile.open(url.split('/')[-1])
            tf.extractall(data_dir)
        else:
            print('Already downloaded', url)

if not os.path.isdir('data'):
    os.mkdir('data')

download_and_extract('data', '.')
# Out:
# Already downloaded http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Already downloaded http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz

# %% [markdown]
# # Extracting Annotations from XML Format

# %%
xml_dir = 'data/annotations/xmls/'
xml_files = [os.path.join(xml_dir, x) for x in os.listdir(xml_dir) if x[-3:] == 'xml']
xml_files[0]
# Out:
# 'data/annotations/xmls/Bengal_155.xml'

# %%
classes = ['cat', 'dog']
categories = [
    {
        'class_id': 0,
        'name': 'cat'
    },
    {
        'class_id': 1,
        'name': 'dog'
    }
]

# %%
def extract_annotation(xml_file_path):
    
    tree = ET.parse(xml_file_path)
    root = tree.getroot()
    annotation = {}
    
    annotation['file'] = root.find('filename').text
    annotation['categories'] = categories
    
    size = root.find('size')
    
    annotation['image_size'] = [{
        'width': int(size.find('width').text),
        'height': int(size.find('height').text),
        'depth': int(size.find('depth').text)
    }]
    
    annotation['annotations'] = []
    
    for item in root.iter('object'):
        class_id = classes.index(item.find('name').text)
        ymin, xmin, ymax, xmax = None, None, None, None
        
        for box in item.findall('bndbox'):
            xmin = int(box.find("xmin").text)
            ymin = int(box.find("ymin").text)
            xmax = int(box.find("xmax").text)
            ymax = int(box.find("ymax").text)
        
            if all([xmin, ymin, xmax, ymax]) is not None:
                 annotation['annotations'].append({
                     'class_id': class_id,
                     'left': xmin,
                     'top': ymin,
                     'width': xmax - xmin,
                     'height': ymax - ymin
                 })
    return annotation

# %%
extract_annotation(xml_files[0])
# Out:
# {'file': 'Bengal_155.jpg',
#  'categories': [{'class_id': 0, 'name': 'cat'},
#   {'class_id': 1, 'name': 'dog'}],
#  'image_size': [{'width': 225, 'height': 300, 'depth': 3}],
#  'annotations': [{'class_id': 0,
#    'left': 26,
#    'top': 68,
#    'width': 179,
#    'height': 191}]}

# %% [markdown]
# # Visualize Data

# %%
def plot_example(plt, annot, image_file_path, rows, cols, index):
    img = Image.open(image_file_path)
    draw = ImageDraw.Draw(img)
    font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSerif-Bold.ttf', 20)
    
    for a in annot['annotations']:
        box = [
            int(a['left']), int(a['top']),
            int(a['left']) + int(a['width']),
            int(a['top']) + int(a['height'])
        ]
        draw.rectangle(box, outline='red', width=4)
        draw.text((box[0], box[1]), classes[int(a['class_id'])], font=font)
    plt.subplot(rows, cols, index + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img)
    return plt

def show_random_annotations(plt):
    plt.figure(figsize=(16, 16))
    for i in range(0, 9):
        index = random.randint(0, len(xml_files) - 1)
        
        annot = extract_annotation(xml_files[index])
        image_file_path = os.path.join('data/images/', annot['file'])

        plt = plot_example(plt, annot, image_file_path, 3, 3, i)
    plt.show()

# %%
show_random_annotations(plt)

# %% [markdown]
# # SageMaker Setup

# %%
role = sagemaker.get_execution_role()
bucket_name = 'petsdata-webapp'

training_image = get_image_uri(boto3.Session().region_name, 'object-detection',
                              repo_version='latest')
print(training_image)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 811284229777.dkr.ecr.us-east-1.amazonaws.com/object-detection:latest

# %%
folders = ['train', 'train_annotation', 'validation', 'validation_annotation']

for folder in folders:
    if os.path.isdir(folder):
        shutil.rmtree(folder)
    os.mkdir(folder)

# %% [markdown]
# # Preparing Data for SageMaker

# %%
print('Total examples:', len(xml_files))
# Out:
# Total examples: 3686

# %%
for xml_file in tqdm(xml_files):
    target_set = 'train' if random.randint(0, 99) < 75 else 'validation'
    annot = extract_annotation(xml_file)
    image_file_path = os.path.join('data/images/', annot['file'])
    image_target_path = os.path.join(target_set, annot['file'])
    shutil.copy(image_file_path, image_target_path)
    json_file_path = os.path.join(target_set + '_annotation', annot['file'][:-3] + 'json')
    with open(json_file_path, 'w') as f:
        json.dump(annot, f)
# Out:
# 100%|██████████| 3686/3686 [00:01<00:00, 2334.68it/s]

# %%
train_images = os.listdir('train')
train_annots = os.listdir('train_annotation')

# %%
print(len(train_annots), len(train_images))
# Out:
# 2756 2756

# %%
for image in train_images:
    key = image.split('.')[0]
    json_file = key + '.json'
    if json_file not in train_annots:
        print('Not found', json_file)

# %% [markdown]
# # Uploading Data to S3

# %%
sess = sagemaker.Session()

print('Uploading data..')
s3_train_path = sess.upload_data(path='train', bucket=bucket_name, key_prefix='train')

print('Training images uploaded')
s3_validation_path = sess.upload_data(path='validation', bucket = bucket_name,
                                     key_prefix='validation')

print('Validation images uploaded')
s3_train_annotation = sess.upload_data(path='train_annotation', bucket = bucket_name,
                                     key_prefix='train_annotation')

print('Training annotation images uploaded')
s3_validation_annotation = sess.upload_data(path='validation_annotation', bucket = bucket_name,
                                     key_prefix='validation_annotation')
print('Validation annotation images uploaded')
# Out:
# Uploading data..
# Training images uploaded
# Validation images uploaded
# Training annotation images uploaded
# Validation annotation images uploaded

# %%
s3_validation_path
# Out:
# 's3://petsdata-webapp/validation'

# %% [markdown]
# # SageMaker Estimator

# %%
model = sagemaker.estimator.Estimator(
    training_image,
    role=role,
    train_instance_type='ml.p3.2xlarge',
    train_instance_count=1,
    train_volume_size=100,
    train_max_run=36000,
    input_mode='File',
    output_path='s3://petsdata-webapp/output',
    sagemaker_session=sess
)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# # Hyperparameters

# %%
model.set_hyperparameters(
    base_network='resnet-50',
    num_classes=2,
    use_pretrained_model=1,
    mini_batch_size=16,
    epochs=15,
    learning_rate=0.001,
    optimizer='sgd',
    lr_scheduler_step='10',
    lr_scheduler_factor=0.1,
    momentum=0.9,
    weight_decay=0.0005,
    overlap_threshold=0.5,
    nms_threshold=0.45,
    image_shape=512,
    num_training_samples=len(train_annots)
)

# %% [markdown]
# # Data Channels

# %%
from sagemaker.session import s3_input

train_data = s3_input(s3_train_path,distribution='FullyReplicated',
                     content_type='application/x-image',s3_data_type='S3Prefix')
validation_data = s3_input(s3_validation_path,distribution='FullyReplicated',
                     content_type='application/x-image',s3_data_type='S3Prefix')
train_annotation_data = s3_input(s3_train_annotation,distribution='FullyReplicated',
                     content_type='application/x-image',s3_data_type='S3Prefix')
validation_annotation_data = s3_input(s3_validation_annotation,distribution='FullyReplicated',
                     content_type='application/x-image',s3_data_type='S3Prefix')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
data_channels = {
    'train': train_data,
    'validation':validation_data,
    'train_annotation': train_annotation_data,
    'validation_annotation':validation_annotation_data
}

# %%
data_channels
# Out:
# {'train': <sagemaker.inputs.s3_input at 0x7fe2978f7b00>,
#  'validation': <sagemaker.inputs.s3_input at 0x7fe2978f74e0>,
#  'train_annotation': <sagemaker.inputs.s3_input at 0x7fe2978f7400>,
#  'validation_annotation': <sagemaker.inputs.s3_input at 0x7fe2978f7da0>}

# %% [markdown]
# # Model Training

# %%
model.fit(inputs=data_channels, logs=True)
# Out:
# 2020-09-21 17:39:56 Starting - Starting the training job...
# 2020-09-21 17:39:57 Starting - Launching requested ML instances.........
# 2020-09-21 17:41:31 Starting - Preparing the instances for training......
# 2020-09-21 17:42:45 Downloading - Downloading input data.........
# 2020-09-21 17:44:12 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# [09/21/2020 17:44:36 INFO 139880692225856] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'30', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'32', u'use_pretrained_model': u'0', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'', u'base_network': u'vgg-16', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'300'}
# [09/21/2020 17:44:36 INFO 139880692225856] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'learning_rate': u'0.001', u'epochs': u'15', u'nms_threshold': u'0.45', u'optimizer': u'sgd', u'base_network': u'resnet-50', u'image_shape': u'512', u'lr_scheduler_step': u'10', u'momentum': u'0.9', u'overlap_threshold': u'0.5', u'num_training_samples': u'2756', u'mini_batch_size': u'16', u'weight_decay': u'0.0005', u'use_pretrained_model': u'1', u'num_classes': u'2', u'lr_scheduler_factor': u'0.1'}
# [09/21/2020 17:44:36 INFO 139880692225856] Final configuration: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'15', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'16', u'use_pretrained_model': u'1', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'10', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'2756', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'2', u'base_network': u'resnet-50', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'512'}
# Process 1 is a worker.
# [09/21/2020 17:44:36 INFO 139880692225856] Using default worker.
# [09/21/2020 17:44:36 INFO 139880692225856] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [09/21/2020 17:44:36 INFO 139880692225856] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [09/21/2020 17:44:36 INFO 139880692225856] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [09/21/2020 17:44:36 INFO 139880692225856] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [09/21/2020 17:44:36 INFO 139880692225856] Checkpoint loading and saving are disabled.
# [09/21/2020 17:44:37 INFO 139880692225856] nvidia-smi took: 0.0251920223236 secs to identify 1 gpus
# Creating .rec file from /opt/ml/input/data/train/train.lst in /opt/ml/input/data/train
# time: 0.0183100700378  count: 0
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# time: 1.32930779457  count: 1000
# Corrupt JPEG data: premature end of data segment
# time: 1.10045003891  count: 2000
# Creating .rec file from /opt/ml/input/data/validation/val.lst in /opt/ml/input/data/validation
# time: 0.00466704368591  count: 0
# [09/21/2020 17:44:43 INFO 139880692225856] Number of GPUs being used: 1
# [09/21/2020 17:44:43 WARNING 139880692225856] Training images are resized to image shape (3, 512, 512)
# [17:44:43] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, use 7 threads for decoding..
# [17:44:43] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, label padding width: 350
#
# 2020-09-21 17:44:33 Training - Training image download completed. Training in progress.[09/21/2020 17:44:46 WARNING 139880692225856] Validation images are resized to image shape (3, 512, 512)
# [17:44:46] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, use 7 threads for decoding..
# [17:44:46] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, label padding width: 350
# [09/21/2020 17:44:48 INFO 139880692225856] Number of GPUs being used: 1
# [09/21/2020 17:44:48 INFO 139880692225856] Using [gpu(0)] as training context.
# [09/21/2020 17:44:48 INFO 139880692225856] Number of GPUs being used: 1
# [09/21/2020 17:44:48 INFO 139880692225856] Create Store: device
# [09/21/2020 17:44:48 INFO 139880692225856] Using (gpu(0)) as training context.
# [09/21/2020 17:44:48 INFO 139880692225856] Start training from pretrained model 1.
# [17:44:48] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [17:44:48] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [09/21/2020 17:44:49 INFO 139880692225856] Loaded pretrained model parameters.
# [09/21/2020 17:45:03 INFO 139880692225856] Creating a new state instance.
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1600710303.839529, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1600710303.839427}
#
# [17:45:04] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [09/21/2020 17:45:41 INFO 139880692225856] Epoch:    0, batches:    100, num_examples:   1600, 42.5 samples/sec, epoch time so far:  0:00:37.673763
# [09/21/2020 17:46:04 INFO 139880692225856] #quality_metric: host=algo-1, epoch=0, batch=173 train cross_entropy <loss>=(1.0997040645732568)
# [09/21/2020 17:46:04 INFO 139880692225856] #quality_metric: host=algo-1, epoch=0, batch=173 train smooth_l1 <loss>=(0.6404442269985676)
# [09/21/2020 17:46:04 INFO 139880692225856] Round of batches complete
# [09/21/2020 17:46:04 INFO 139880692225856] Updated the metrics
# [09/21/2020 17:46:16 INFO 139880692225856] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(0.12203495993936575)
# [09/21/2020 17:46:16 INFO 139880692225856] Updating the best model with validation-mAP=0.12203495993936575
# [09/21/2020 17:46:16 INFO 139880692225856] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/21/2020 17:46:16 INFO 139880692225856] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1600710376.142896, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 0}, "StartTime": 1600710303.839951}
#
# [09/21/2020 17:46:48 INFO 139880692225856] Epoch:    1, batches:    100, num_examples:   1600, 49.1 samples/sec, epoch time so far:  0:00:32.583663
# [09/21/2020 17:47:10 INFO 139880692225856] #quality_metric: host=algo-1, epoch=1, batch=172 train cross_entropy <loss>=(0.8638401250641617)
# [09/21/2020 17:47:10 INFO 139880692225856] #quality_metric: host=algo-1, epoch=1, batch=172 train smooth_l1 <loss>=(0.5859473164672148)
# [09/21/2020 17:47:10 INFO 139880692225856] Round of batches complete
# [09/21/2020 17:47:10 INFO 139880692225856] Updated the metrics
# [09/21/2020 17:47:21 INFO 139880692225856] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(0.3533752539651405)
# [09/21/2020 17:47:21 INFO 139880692225856] Updating the best model with validation-mAP=0.3533752539651405
# [09/21/2020 17:47:21 INFO 139880692225856] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/21/2020 17:47:21 INFO 139880692225856] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1600710441.59711, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 1}, "StartTime": 1600710376.14315}
#
# [09/21/2020 17:47:54 INFO 139880692225856] Epoch:    2, batches:    100, num_examples:   1600, 48.7 samples/sec, epoch time so far:  0:00:32.828428
# [09/21/2020 17:48:16 INFO 139880692225856] #quality_metric: host=algo-1, epoch=2, batch=172 train cross_entropy <loss>=(0.731083211017961)
# [09/21/2020 17:48:16 INFO 139880692225856] #quality_metric: host=algo-1, epoch=2, batch=172 train smooth_l1 <loss>=(0.5286026496688923)
# [09/21/2020 17:48:16 INFO 139880692225856] Round of batches complete
# [09/21/2020 17:48:16 INFO 139880692225856] Updated the metrics
# [09/21/2020 17:48:26 INFO 139880692225856] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(0.6527504418673407)
# [09/21/2020 17:48:26 INFO 139880692225856] Updating the best model with validation-mAP=0.6527504418673407
# [09/21/2020 17:48:26 INFO 139880692225856] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/21/2020 17:48:26 INFO 139880692225856] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1600710506.998887, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 2}, "StartTime": 1600710441.597381}
#
# [09/21/2020 17:49:00 INFO 139880692225856] Epoch:    3, batches:    100, num_examples:   1600, 48.3 samples/sec, epoch time so far:  0:00:33.117567
# [09/21/2020 17:49:21 INFO 139880692225856] #quality_metric: host=algo-1, epoch=3, batch=172 train cross_entropy <loss>=(0.6455393364657013)
# [09/21/2020 17:49:21 INFO 139880692225856] #quality_metric: host=algo-1, epoch=3, batch=172 train smooth_l1 <loss>=(0.4578141802746558)
# [09/21/2020 17:49:21 INFO 139880692225856] Round of batches complete
# [09/21/2020 17:49:21 INFO 139880692225856] Updated the metrics
# [09/21/2020 17:49:32 INFO 139880692225856] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.8134400398477831)
# [09/21/2020 17:49:32 INFO 139880692225856] Updating the best model with validation-mAP=0.8134400398477831
# [09/21/2020 17:49:32 INFO 139880692225856] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/21/2020 17:49:33 INFO 139880692225856] #progress_metric: host=algo-1, completed 26 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1600710573.001148, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 3}, "StartTime": 1600710506.999142}
#
# [09/21/2020 17:50:07 INFO 139880692225856] Epoch:    4, batches:    100, num_examples:   1600, 46.1 samples/sec, epoch time so far:  0:00:34.731897
# [09/21/2020 17:50:29 INFO 139880692225856] #quality_metric: host=algo-1, epoch=4, batch=173 train cross_entropy <loss>=(0.5975237023906711)
# [09/21/2020 17:50:29 INFO 139880692225856] #quality_metric: host=algo-1, epoch=4, batch=173 train smooth_l1 <loss>=(0.3806434563677776)
# [09/21/2020 17:50:29 INFO 139880692225856] Round of batches complete
# [09/21/2020 17:50:30 INFO 139880692225856] Updated the metrics
# [09/21/2020 17:50:41 INFO 139880692225856] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(0.881250304857716)
# [09/21/2020 17:50:41 INFO 139880692225856] Updating the best model with validation-mAP=0.881250304857716
# [09/21/2020 17:50:41 INFO 139880692225856] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/21/2020 17:50:41 INFO 139880692225856] #progress_metric: host=algo-1, completed 33 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1600710641.648447, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 4}, "StartTime": 1600710573.001423}
#
# [09/21/2020 17:51:14 INFO 139880692225856] Epoch:    5, batches:    100, num_examples:   1600, 49.1 samples/sec, epoch time so far:  0:00:32.589721
# [09/21/2020 17:51:36 INFO 139880692225856] #quality_metric: host=algo-1, epoch=5, batch=172 train cross_entropy <loss>=(0.5673224970073065)
# [09/21/2020 17:51:36 INFO 139880692225856] #quality_metric: host=algo-1, epoch=5, batch=172 train smooth_l1 <loss>=(0.33303352466644937)
# [09/21/2020 17:51:36 INFO 139880692225856] Round of batches complete
# [09/21/2020 17:51:36 INFO 139880692225856] Updated the metrics
# [09/21/2020 17:51:48 INFO 139880692225856] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.9444072149478249)
# [09/21/2020 17:51:48 INFO 139880692225856] Updating the best model with validation-mAP=0.9444072149478249
# [09/21/2020 17:51:48 INFO 139880692225856] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/21/2020 17:51:48 INFO 139880692225856] #progress_metric: host=algo-1, completed 40 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1600710708.745699, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 5}, "StartTime": 1600710641.648817}
#
# [09/21/2020 17:52:21 INFO 139880692225856] Epoch:    6, batches:    100, num_examples:   1600, 48.9 samples/sec, epoch time so far:  0:00:32.719676
# [09/21/2020 17:52:43 INFO 139880692225856] #quality_metric: host=algo-1, epoch=6, batch=172 train cross_entropy <loss>=(0.5399095563554771)
# [09/21/2020 17:52:43 INFO 139880692225856] #quality_metric: host=algo-1, epoch=6, batch=172 train smooth_l1 <loss>=(0.2939073513162574)
# [09/21/2020 17:52:43 INFO 139880692225856] Round of batches complete
# [09/21/2020 17:52:43 INFO 139880692225856] Updated the metrics
# [09/21/2020 17:52:55 INFO 139880692225856] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(0.9701041521664695)
# [09/21/2020 17:52:55 INFO 139880692225856] Updating the best model with validation-mAP=0.9701041521664695
# [09/21/2020 17:52:55 INFO 139880692225856] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/21/2020 17:52:55 INFO 139880692225856] #progress_metric: host=algo-1, completed 46 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1600710775.641947, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 6}, "StartTime": 1600710708.746013}
#
# [09/21/2020 17:53:28 INFO 139880692225856] Epoch:    7, batches:    100, num_examples:   1600, 49.3 samples/sec, epoch time so far:  0:00:32.448591
# [09/21/2020 17:53:49 INFO 139880692225856] #quality_metric: host=algo-1, epoch=7, batch=172 train cross_entropy <loss>=(0.5167547360713116)
# [09/21/2020 17:53:49 INFO 139880692225856] #quality_metric: host=algo-1, epoch=7, batch=172 train smooth_l1 <loss>=(0.27180258654872835)
# [09/21/2020 17:53:49 INFO 139880692225856] Round of batches complete
# [09/21/2020 17:53:49 INFO 139880692225856] Updated the metrics
# [09/21/2020 17:54:00 INFO 139880692225856] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.9824025467566485)
# [09/21/2020 17:54:00 INFO 139880692225856] Updating the best model with validation-mAP=0.9824025467566485
# [09/21/2020 17:54:00 INFO 139880692225856] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/21/2020 17:54:00 INFO 139880692225856] #progress_metric: host=algo-1, completed 53 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1600710840.963859, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 7}, "StartTime": 1600710775.642169}
#
# [09/21/2020 17:54:35 INFO 139880692225856] Epoch:    8, batches:    100, num_examples:   1600, 46.9 samples/sec, epoch time so far:  0:00:34.102472
# [09/21/2020 17:54:57 INFO 139880692225856] #quality_metric: host=algo-1, epoch=8, batch=173 train cross_entropy <loss>=(0.5037550694677538)
# [09/21/2020 17:54:57 INFO 139880692225856] #quality_metric: host=algo-1, epoch=8, batch=173 train smooth_l1 <loss>=(0.2508077626804852)
# [09/21/2020 17:54:57 INFO 139880692225856] Round of batches complete
# [09/21/2020 17:54:57 INFO 139880692225856] Updated the metrics
# [09/21/2020 17:55:10 INFO 139880692225856] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(0.9863970481293773)
# [09/21/2020 17:55:10 INFO 139880692225856] Updating the best model with validation-mAP=0.9863970481293773
# [09/21/2020 17:55:10 INFO 139880692225856] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/21/2020 17:55:10 INFO 139880692225856] #progress_metric: host=algo-1, completed 60 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1600710910.414284, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 8}, "StartTime": 1600710840.964211}
#
# [09/21/2020 17:55:42 INFO 139880692225856] Epoch:    9, batches:    100, num_examples:   1600, 49.4 samples/sec, epoch time so far:  0:00:32.366543
# [09/21/2020 17:56:04 INFO 139880692225856] #quality_metric: host=algo-1, epoch=9, batch=172 train cross_entropy <loss>=(0.4789795079697995)
# [09/21/2020 17:56:04 INFO 139880692225856] #quality_metric: host=algo-1, epoch=9, batch=172 train smooth_l1 <loss>=(0.23013714401560764)
# [09/21/2020 17:56:04 INFO 139880692225856] Round of batches complete
# [09/21/2020 17:56:04 INFO 139880692225856] Updated the metrics
# [09/21/2020 17:56:16 INFO 139880692225856] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(0.9875271015707489)
# [09/21/2020 17:56:16 INFO 139880692225856] Updating the best model with validation-mAP=0.9875271015707489
# [09/21/2020 17:56:16 INFO 139880692225856] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/21/2020 17:56:16 INFO 139880692225856] #progress_metric: host=algo-1, completed 66 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1600710976.70986, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 9}, "StartTime": 1600710910.414581}
#
# [09/21/2020 17:56:48 INFO 139880692225856] Epoch:    10, batches:    100, num_examples:   1600, 49.9 samples/sec, epoch time so far:  0:00:32.083218
# [09/21/2020 17:57:10 INFO 139880692225856] #quality_metric: host=algo-1, epoch=10, batch=172 train cross_entropy <loss>=(0.45982418902906547)
# [09/21/2020 17:57:10 INFO 139880692225856] #quality_metric: host=algo-1, epoch=10, batch=172 train smooth_l1 <loss>=(0.2135330264826855)
# [09/21/2020 17:57:10 INFO 139880692225856] Round of batches complete
# [09/21/2020 17:57:10 INFO 139880692225856] Updated the metrics
# [09/21/2020 17:57:22 INFO 139880692225856] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(0.9903575777420706)
# [09/21/2020 17:57:22 INFO 139880692225856] Updating the best model with validation-mAP=0.9903575777420706
# [09/21/2020 17:57:22 INFO 139880692225856] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/21/2020 17:57:22 INFO 139880692225856] #progress_metric: host=algo-1, completed 73 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1600711042.470976, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 10}, "StartTime": 1600710976.71013}
#
# [09/21/2020 17:57:54 INFO 139880692225856] Epoch:    11, batches:    100, num_examples:   1600, 49.4 samples/sec, epoch time so far:  0:00:32.385982
# [09/21/2020 17:58:16 INFO 139880692225856] #quality_metric: host=algo-1, epoch=11, batch=172 train cross_entropy <loss>=(0.4497138190396)
# [09/21/2020 17:58:16 INFO 139880692225856] #quality_metric: host=algo-1, epoch=11, batch=172 train smooth_l1 <loss>=(0.20438314389182305)
# [09/21/2020 17:58:16 INFO 139880692225856] Round of batches complete
# [09/21/2020 17:58:16 INFO 139880692225856] Updated the metrics
# [09/21/2020 17:58:27 INFO 139880692225856] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.9906489808632631)
# [09/21/2020 17:58:27 INFO 139880692225856] Updating the best model with validation-mAP=0.9906489808632631
# [09/21/2020 17:58:27 INFO 139880692225856] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/21/2020 17:58:27 INFO 139880692225856] #progress_metric: host=algo-1, completed 80 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1600711107.958222, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 11}, "StartTime": 1600711042.471341}
#
# [09/21/2020 17:59:02 INFO 139880692225856] Epoch:    12, batches:    100, num_examples:   1600, 46.9 samples/sec, epoch time so far:  0:00:34.105445
# [09/21/2020 17:59:23 INFO 139880692225856] #quality_metric: host=algo-1, epoch=12, batch=173 train cross_entropy <loss>=(0.43438193682106085)
# [09/21/2020 17:59:23 INFO 139880692225856] #quality_metric: host=algo-1, epoch=12, batch=173 train smooth_l1 <loss>=(0.1873948676214939)
# [09/21/2020 17:59:23 INFO 139880692225856] Round of batches complete
# [09/21/2020 17:59:24 INFO 139880692225856] Updated the metrics
# [09/21/2020 17:59:35 INFO 139880692225856] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.9904075272242432)
# [09/21/2020 17:59:35 INFO 139880692225856] #progress_metric: host=algo-1, completed 86 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1600711175.637233, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 12}, "StartTime": 1600711107.958472}
#
# [09/21/2020 18:00:08 INFO 139880692225856] Epoch:    13, batches:    100, num_examples:   1600, 49.3 samples/sec, epoch time so far:  0:00:32.436195
# [09/21/2020 18:00:29 INFO 139880692225856] #quality_metric: host=algo-1, epoch=13, batch=172 train cross_entropy <loss>=(0.4296733876461614)
# [09/21/2020 18:00:29 INFO 139880692225856] #quality_metric: host=algo-1, epoch=13, batch=172 train smooth_l1 <loss>=(0.1855392999837317)
# [09/21/2020 18:00:29 INFO 139880692225856] Round of batches complete
# [09/21/2020 18:00:30 INFO 139880692225856] Updated the metrics
# [09/21/2020 18:00:41 INFO 139880692225856] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.9897662523981359)
# [09/21/2020 18:00:41 INFO 139880692225856] #progress_metric: host=algo-1, completed 93 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1600711241.63511, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 13}, "StartTime": 1600711175.637467}
#
# [09/21/2020 18:01:13 INFO 139880692225856] Epoch:    14, batches:    100, num_examples:   1600, 49.7 samples/sec, epoch time so far:  0:00:32.174718
# [09/21/2020 18:01:35 INFO 139880692225856] #quality_metric: host=algo-1, epoch=14, batch=172 train cross_entropy <loss>=(0.4114326358676792)
# [09/21/2020 18:01:35 INFO 139880692225856] #quality_metric: host=algo-1, epoch=14, batch=172 train smooth_l1 <loss>=(0.17377168370916082)
# [09/21/2020 18:01:35 INFO 139880692225856] Round of batches complete
# [09/21/2020 18:01:35 INFO 139880692225856] Updated the metrics
#
# 2020-09-21 18:02:07 Uploading - Uploading generated training model
# 2020-09-21 18:02:07 Completed - Training job completed
# [09/21/2020 18:01:47 INFO 139880692225856] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(0.9924906851227928)
# [09/21/2020 18:01:47 INFO 139880692225856] Updating the best model with validation-mAP=0.9924906851227928
# [09/21/2020 18:01:47 INFO 139880692225856] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/21/2020 18:01:47 INFO 139880692225856] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1600711307.345516, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 14}, "StartTime": 1600711241.635349}
#
# [09/21/2020 18:01:47 WARNING 139880692225856] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/21/2020 18:01:47 INFO 139880692225856] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/21/2020 18:01:47 INFO 139880692225856] Test data is not provided.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}, "totaltime": {"count": 1, "max": 1031889.3618583679, "sum": 1031889.3618583679, "min": 1031889.3618583679}, "setuptime": {"count": 1, "max": 10.104894638061523, "sum": 10.104894638061523, "min": 10.104894638061523}}, "EndTime": 1600711308.545343, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1600710276.7779}
#
# Training seconds: 1162
# Billable seconds: 1162

# %% [markdown]
# # Deploy Model

# %%
deployed_model = model.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge')
print('\nModel deployed!')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# ------------------!
# Model deployed!

# %% [markdown]
# # Predictions

# %%
image_dir = 'validation'
images = [x for x in os.listdir(image_dir) if x[-3:] == 'jpg']
print(len(images))
# Out:
# 930

# %%
deployed_model.content_type='image/jpeg'

# %%
index = 0

image_path = os.path.join(image_dir, images[index])
#image_path = 'pomeranian_187.jpg'

with open(image_path, 'rb') as f:
    b = bytearray(f.read())

results = deployed_model.predict(b)
results = json.loads(results)

preds = results['prediction']

# %%
preds[0]
# Out:
# [1.0,
#  0.8965703248977661,
#  0.12052083015441895,
#  0.06738254427909851,
#  0.8763711452484131,
#  0.6390154361724854]

# %%
img = Image.open(image_path)
draw = ImageDraw.Draw(img)
font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSerif-Bold.ttf', 30)
w, h =img.size

for pred in preds:
    class_id, score, xmin, ymin, xmax, ymax = pred
    
    if score > 0.7:
        box = [w*xmin, h*ymin, w*xmax, h*ymax]

        draw.rectangle(box, outline='yellow', width=4)
        draw.text((box[0], box[1]), classes[int(class_id)], font=font, fill='#000000')
    else:
        break

plt.xticks([])
plt.yticks([])
plt.imshow(img)
plt.show()

# %% [markdown]
# Don't forget!! You need to delete endpoint or else you will continue to accrue cost!

# %%
sagemaker.Session().delete_endpoint(deployed_model.endpoint)
